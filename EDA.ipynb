# %% [markdown]
# # Explanatory Data Analysis＝探索的データ分析

# %%
import pandas as pd
import glob
import matplotlib as mpl
import matplotlib.pyplot as plt  # これを呼ばないと matplotlib.font_manager にアクセスできない


def show_avaiable_fonts():
    print("Avaiable fonts:")
    for font in mpl.font_manager.findSystemFonts():
        fontname = mpl.font_manager.FontProperties(fname=font).get_name()
        print(f"* {fontname}")
# 利用可能なフォントを表示する。
show_avaiable_fonts()
# Out:
# Avaiable fonts:
# * DejaVu Math TeX Gyre
# * Latin Modern Roman Unslanted
# * Laksaman
# * Lohit Assamese
# * Lohit Kannada
# * Vemana2000
# * Jamrul
# * Latin Modern Roman
# * Latin Modern Sans
# * URW Gothic
# * TeX Gyre Heros
# * Latin Modern Roman
# * Noto Sans CJK JP
# * Latin Modern Mono Caps
# * Lato
# * Liberation Mono
# * Liberation Sans Narrow
# * OpenSymbol
# * Nimbus Roman
# * Latin Modern Mono Light Cond
# * Z003
# * Kalimati
# * TeX Gyre Adventor
# * Latin Modern Roman
# * Latin Modern Mono Caps
# * Kalapi
# * Sarai
# * TeX Gyre Termes Math
# * Ubuntu
# * TeX Gyre Heros Cn
# * Tlwg Mono
# * Latin Modern Roman
# * Nimbus Sans Narrow
# * KacstOne
# * Sahadeva
# * Latin Modern Mono Prop
# * KacstNaskh
# * Nimbus Sans Narrow
# * Garuda
# * Liberation Mono
# * DejaVu Sans
# * Nimbus Roman
# * DejaVu Serif
# * Tlwg Typo
# * Ubuntu
# * DejaVu Sans
# * msbm10
# * Yrsa
# * FreeSerif
# * Rasa
# * DejaVu Sans Mono
# * Tlwg Typewriter
# * Rasa
# * URW Gothic
# * P052
# * Keraleeyam
# * C059
# * cmmi10
# * KacstScreen
# * KacstPen
# * DejaVu Sans Mono
# * Latin Modern Sans
# * Tlwg Mono
# * Pagul
# * Liberation Mono
# * DejaVu Sans
# * Latin Modern Mono Light Cond
# * TeX Gyre Bonum Math
# * Tlwg Typewriter
# * Saab
# * DejaVu Sans
# * KacstQurn
# * Ubuntu
# * Rasa
# * Liberation Mono
# * Noto Serif CJK JP
# * Liberation Serif
# * KacstLetter
# * Noto Sans CJK JP
# * TeX Gyre Cursor
# * Latin Modern Mono
# * Liberation Serif
# * FreeSans
# * Samyak Gujarati
# * FreeSerif
# * Latin Modern Sans Quotation
# * C059
# * FreeSans
# * Tlwg Mono
# * DejaVu Sans
# * Laksaman
# * Karumbi
# * Lohit Tamil
# * Kinnari
# * Noto Sans CJK JP
# * Lohit Telugu
# * Latin Modern Roman
# * Lato
# * Waree
# * Noto Serif CJK JP
# * eufm10
# * Latin Modern Sans Quotation
# * Lato
# * DejaVu Serif
# * Latin Modern Sans Quotation
# * TeX Gyre Pagella
# * Tlwg Typist
# * Liberation Mono
# * Gayathri
# * TeX Gyre Bonum
# * Lato
# * Latin Modern Roman
# * Kinnari
# * Standard Symbols PS
# * Latin Modern Sans Demi Cond
# * TeX Gyre Schola
# * P052
# * Nimbus Sans
# * Ubuntu
# * Waree
# * Ubuntu
# * Latin Modern Roman
# * Latin Modern Sans
# * Nimbus Roman
# * DejaVu Serif
# * Latin Modern Sans
# * Rachana
# * KacstDigital
# * URW Gothic
# * Latin Modern Sans
# * Nimbus Sans Narrow
# * Mukti Narrow
# * FreeMono
# * Loma
# * TeX Gyre DejaVu Math
# * Latin Modern Mono Prop Light
# * TeX Gyre Heros Cn
# * Liberation Sans Narrow
# * Latin Modern Roman Caps
# * Norasi
# * Sawasdee
# * Liberation Serif
# * Chandas
# * Chilanka
# * Umpush
# * KacstOne
# * Latin Modern Roman Demi
# * padmaa
# * Latin Modern Roman Slanted
# * FreeSerif
# * TeX Gyre Heros
# * Laksaman
# * Noto Serif CJK JP
# * TeX Gyre Schola
# * padmaa-Bold.1.1
# * Ubuntu
# * TeX Gyre Termes
# * Liberation Sans Narrow
# * Liberation Sans
# * Latin Modern Roman Slanted
# * Noto Serif CJK JP
# * Padauk
# * TeX Gyre Heros
# * Liberation Serif
# * Lato
# * URW Gothic
# * Tlwg Typo
# * Yrsa
# * Lohit Gujarati
# * Lato
# * cmex10
# * Tlwg Typewriter
# * Garuda
# * Liberation Mono
# * Nimbus Mono PS
# * Latin Modern Roman
# * Pothana2000
# * Padauk Book
# * TeX Gyre Chorus
# * Latin Modern Sans
# * LKLUG
# * Nimbus Sans
# * Droid Sans Fallback
# * DejaVu Sans Mono
# * KacstBook
# * C059
# * Latin Modern Mono Prop
# * URW Bookman
# * GFS Porson
# * Dyuthi
# * Latin Modern Mono Prop Light
# * TeX Gyre Bonum
# * KacstTitle
# * Latin Modern Roman Slanted
# * Latin Modern Sans Demi Cond
# * Padauk
# * Abyssinica SIL
# * Latin Modern Roman Slanted
# * KacstFarsi
# * msam10
# * Loma
# * Nimbus Mono PS
# * Waree
# * Sawasdee
# * Rasa
# * Lohit Gurmukhi
# * Noto Serif CJK JP
# * Latin Modern Roman
# * FreeMono
# * TeX Gyre Termes
# * Purisa
# * Rachana
# * aakar
# * Ani
# * Latin Modern Roman
# * DejaVu Sans
# * DejaVu Serif
# * URW Bookman
# * TeX Gyre Cursor
# * Latin Modern Mono Slanted
# * Umpush
# * Nakula
# * Lato
# * Latin Modern Roman
# * Latin Modern Roman Dunhill
# * Umpush
# * Latin Modern Roman
# * TeX Gyre Cursor
# * Sawasdee
# * Latin Modern Mono
# * TeX Gyre Adventor
# * TeX Gyre Adventor
# * Khmer OS
# * Latin Modern Mono Light
# * Norasi
# * esint10
# * Samyak Devanagari
# * Waree
# * Navilu
# * Umpush
# * rsfs10
# * Liberation Sans
# * Liberation Serif
# * Lato
# * DejaVu Sans
# * Latin Modern Roman Demi
# * Noto Sans CJK JP
# * TeX Gyre Cursor
# * Ubuntu Mono
# * Lohit Devanagari
# * DejaVu Serif
# * Tlwg Typist
# * P052
# * Latin Modern Roman
# * Tlwg Mono
# * TeX Gyre Schola
# * cmr10
# * TeX Gyre Adventor
# * Nimbus Sans
# * Uroob
# * FreeSans
# * Latin Modern Mono Prop Light
# * Gayathri
# * Latin Modern Mono
# * Nimbus Sans
# * Sawasdee
# * URW Bookman
# * GFS Baskerville
# * Latin Modern Sans
# * Liberation Mono
# * Ubuntu Mono
# * TeX Gyre Heros Cn
# * Ubuntu Mono
# * Latin Modern Sans
# * stmary10
# * Latin Modern Sans Quotation
# * Nimbus Mono PS
# * Likhan
# * Kinnari
# * TeX Gyre Schola
# * Noto Serif CJK JP
# * Tlwg Typo
# * Ubuntu Mono
# * FreeMono
# * Samyak Tamil
# * TeX Gyre Pagella
# * KacstPoster
# * Norasi
# * Liberation Sans Narrow
# * Latin Modern Roman Caps
# * Loma
# * FreeSerif
# * Garuda
# * Liberation Mono
# * Latin Modern Roman
# * Latin Modern Roman
# * Loma
# * Samanata
# * TeX Gyre Heros
# * Latin Modern Roman
# * Latin Modern Roman
# * Liberation Serif
# * Norasi
# * Latin Modern Roman Slanted
# * Kinnari
# * Ubuntu
# * Latin Modern Roman Slanted
# * Liberation Sans
# * Tlwg Typo
# * Noto Sans CJK JP
# * Latin Modern Roman
# * DejaVu Sans Mono
# * Padauk Book
# * Latin Modern Roman
# * Lato
# * Tlwg Typewriter
# * Lato
# * Latin Modern Mono
# * DejaVu Serif
# * Liberation Sans
# * Latin Modern Mono
# * Mukti Narrow
# * Purisa
# * Latin Modern Mono Light
# * Kinnari
# * DejaVu Serif
# * Noto Sans CJK JP
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /tmp/ipykernel_61180/1047778190.py in <module>
#      13
#      14 # 利用可能なフォントを表示する。
# ---> 15 show_avaiable_fonts()
#
# /tmp/ipykernel_61180/1047778190.py in show_avaiable_fonts()
#       8     print("Avaiable fonts:")
#       9     for font in mpl.font_manager.findSystemFonts():
# ---> 10         fontname = mpl.font_manager.FontProperties(fname=font).get_name()
#      11         print(f"* {fontname}")
#      12
#
# ~/.local/lib/python3.8/site-packages/matplotlib/font_manager.py in get_name(self)
#     722         Return the name of the font that best matches the font properties.
#     723         """
# --> 724         return get_font(findfont(self)).family_name
#     725
#     726     def get_style(self):
#
# ~/.local/lib/python3.8/site-packages/matplotlib/font_manager.py in get_font(filename, hinting_factor)
#    1422         hinting_factor = rcParams['text.hinting_factor']
#    1423     # also key on the thread ID to prevent segfaults with multi-threading
# -> 1424     return _get_font(filename, hinting_factor,
#    1425                      _kerning_factor=rcParams['text.kerning_factor'],
#    1426                      thread_id=threading.get_ident())
#
# ~/.local/lib/python3.8/site-packages/matplotlib/font_manager.py in _get_font(filename, hinting_factor, _kerning_factor, thread_id)
#    1403 @lru_cache(64)
#    1404 def _get_font(filename, hinting_factor, *, _kerning_factor, thread_id):
# -> 1405     return ft2font.FT2Font(
#    1406         filename, hinting_factor, _kerning_factor=_kerning_factor)
#    1407
#
# RuntimeError: In FT2Font: Can not load face.  Unknown file format.

# %%
print(mpl.matplotlib_fname()) #設定ファイルを表示（matplotlibrcは後で作ります）
print(mpl.rcParams['font.family']) #現在使用しているフォントを表示
print(mpl.get_configdir()) #設定ディレクトリを表示
print(mpl.get_cachedir()) #キャッシュディレクトリを表示
# Out:
# /home/xiangze/.local/lib/python3.8/site-packages/matplotlib/mpl-data/matplotlibrc
# ['Hiragino Maru Gothic Pro']
# /home/xiangze/.config/matplotlib
# /home/xiangze/.cache/matplotlib

# %%
plt.rcParams['font.family'] = 'Noto Sans CJK JP'

# %%
N=18

# %% [markdown]
# # CSVファイル

# %% [markdown]
# 番号ごとにcsvファイルをソートする

# %%
#https://stackoverflow.com/questions/5967500/how-to-correctly-sort-a-string-with-a-number-inside
import re

def atoi(text):
    return int(text) if text.isdigit() else text

def natural_keys(text):
    '''
    alist.sort(key=natural_keys) sorts in human order
    http://nedbatchelder.com/blog/200712/human_sorting.html
    (See Toothy's implementation in the comments)
    '''
    return [ atoi(c) for c in re.split(r'(\d+)', text) ]

# %%
charfiles=glob.glob("data/*/*人妖*.csv")+glob.glob("data/*/*キャラ*.csv")
charfiles.sort(key=natural_keys)
charfiles
# Out:
# ['data/1/東方シリーズキャラ人気投票 [Vote Top].csv',
#  'data/2/第２回東方シリーズ人気投票 キャラ部門結果.csv',
#  'data/3/第３回東方シリーズ人気投票 キャラ部門集計結果.csv',
#  'data/4/第４回東方シリーズ人気投票 キャラ部門集計結果.csv',
#  'data/5/第５回東方シリーズ人気投票 キャラ部門集計結果.csv',
#  'data/6/第６回東方シリーズ人気投票 キャラ部門集計結果.csv',
#  'data/7/第７回東方シリーズ人気投票 キャラ部門集計結果.csv',
#  'data/8/第８回東方シリーズ人気投票 キャラ部門集計結果.csv',
#  'data/9/第９回東方シリーズ人気投票 キャラ部門集計結果.csv',
#  'data/10/第１０回東方シリーズ人気投票 キャラ部門集計結果.csv',
#  'data/11/キャラ部門投票結果 - 第11回 東方Project 人気投票.csv',
#  'data/12/人妖部門投票結果 - 第12回 東方Project 人気投票.csv',
#  'data/13/人妖部門投票結果 - 第13回 東方Project 人気投票.csv',
#  'data/14/人妖部門投票結果 - 第14回 東方Project 人気投票.csv',
#  'data/15/人妖部門投票結果 - 第15回 東方Project 人気投票.csv',
#  'data/16/人妖部門投票結果 - 第16回 東方Project 人気投票.csv',
#  'data/17/人妖.csv',
#  'data/17/第18回東方Project人気投票_人妖.csv',
#  'data/18/第18回東方Project人気投票_人妖.csv']

# %%
musicfiles=glob.glob("data/*/*音楽*.csv")
musicfiles.sort(key=natural_keys)
musicfiles
# Out:
# ['data/1/東方シリーズ音楽人気投票 [Vote Top].csv',
#  'data/1/東方シリーズ音楽人気投票 [Vote Top]_iro.csv',
#  'data/2/第２回東方シリーズ人気投票 音楽部門結果.csv',
#  'data/3/第３回東方シリーズ人気投票 音楽部門集計結果.csv',
#  'data/4/第４回東方シリーズ人気投票 音楽部門集計結果.csv',
#  'data/5/第５回東方シリーズ人気投票 音楽部門集計結果.csv',
#  'data/6/第６回東方シリーズ人気投票 音楽部門集計結果.csv',
#  'data/7/第７回東方シリーズ人気投票 音楽部門集計結果.csv',
#  'data/8/第８回東方シリーズ人気投票 音楽部門集計結果.csv',
#  'data/9/第９回東方シリーズ人気投票 音楽部門集計結果.csv',
#  'data/10/第１０回東方シリーズ人気投票 音楽部門集計結果.csv',
#  'data/11/音楽部門投票結果 - 第11回 東方Project 人気投票.csv',
#  'data/12/音楽部門投票結果 - 第12回 東方Project 人気投票.csv',
#  'data/13/音楽部門投票結果 - 第13回 東方Project 人気投票.csv',
#  'data/14/音楽部門投票結果 - 第14回 東方Project 人気投票.csv',
#  'data/15/音楽部門投票結果 - 第15回 東方Project 人気投票.csv',
#  'data/16/音楽部門投票結果 - 第16回 東方Project 人気投票.csv',
#  'data/17/音楽.csv',
#  'data/18/第18回東方Project人気投票_音楽.csv']

# %%
titlefiles=glob.glob("data/*/*作品*.csv")
titlefiles.sort()
titlefiles
# Out:
# ['data/12/作品部門投票結果 - 第12回 東方Project 人気投票.csv',
#  'data/13/作品部門投票結果 - 第13回 東方Project 人気投票.csv',
#  'data/14/作品部門投票結果 - 第14回 東方Project 人気投票.csv',
#  'data/15/作品部門投票結果 - 第15回 東方Project 人気投票.csv',
#  'data/16/作品部門投票結果 - 第16回 東方Project 人気投票.csv',
#  'data/17/作品.csv',
#  'data/18/第18回東方Project人気投票_作品.csv']

# %% [markdown]
# # キャラクター(人妖)部門

# %%
print(charfiles[1])
pd.read_csv(charfiles[1])
# Out:
# data/10/第１０回東方シリーズ人気投票 キャラ部門集計結果.csv
#      Unnamed: 0 Unnamed: 1 Unnamed: 2             名前  Unnamed: 4  Unnamed: 5  \
# 0             1          1          1          博麗 霊夢        7314        1507
# 1             2          5          5         霧雨 魔理沙        6495        1447
# 2             3         14         15        古明地 こいし        6063        1105
# 3             4          3          2         十六夜 咲夜        5848        1286
# 4             5          6          9  フランドール・スカーレット        5488        1091
# ..          ...        ...        ...            ...         ...         ...
# 154         155          -          -            座敷童           5           0
# 155         156          -          -            煙々羅           4           0
# 156         156          -          -        野鉄砲（マミ）           4           0
# 157         156        133        123           毘沙門天           4           0
# 158         159          -          -             沓頬           1           0
#
#      Unnamed: 6
# 0    1732[コメント]
# 1    1470[コメント]
# 2    1363[コメント]
# 3    1242[コメント]
# 4    1235[コメント]
# ..          ...
# 154     2[コメント]
# 155     3[コメント]
# 156     2[コメント]
# 157     1[コメント]
# 158     1[コメント]
#
# [159 rows x 7 columns]

# %%
pd.read_csv(charfiles[2])
# Out:
#       順位   前回   前々             名前  ポイント   一押し  コメント 支援リンク
# 0      1    3   14        古明地 こいし  7859  1603  1503    3件    詳細
# 1      2    1    1          博麗 霊夢  7332  1648  1385    9件    詳細
# 2      3    2    5         霧雨 魔理沙  7227  1719  1477   10件    詳細
# 3      4    4    3         十六夜 咲夜  6241  1361  1060    3件    詳細
# 4      5    5    6  フランドール・スカーレット  5972  1204  1095    5件    詳細
# ..   ...  ...  ...            ...   ...   ...   ...   ...   ...
# 167  168  156    -        野鉄砲（マミ）     4     0     1    0件  コメント
# 168  169  149  140             子龍     3     1     0    0件  コメント
# 169  170    -    -           緑の小人     2     0     1    0件  コメント
# 170  171  149  134            大ガマ     1     0     0    0件  コメント
# 171  172  147  136          水江浦島子     0     0     0    0件  コメント
#
# [172 rows x 9 columns]

# %%
i=11
char_columns=pd.read_csv(charfiles[i]).columns
music_columns=pd.read_csv(musicfiles[i]).columns
i=3
title_columns=pd.read_csv(titlefiles[i]).columns
print(char_columns)
print(music_columns)
print(title_columns)
# Out:
# Index(['順位', '前回', '前々', '名前', 'ポイント', '一押し', 'コメント', '支援作品', '　'], dtype='object')
# Index(['順位', '前回', '前々', '名前', 'ポイント', '一押し', 'コメント', '　'], dtype='object')
# Index(['順位', '前回', '前々', '名前', 'ポイント', '一押し', 'コメント', '　'], dtype='object')

# %%
chars=[]
chars_rank=[]
for i,f in enumerate(charfiles):
    df=pd.read_csv(f)
    df=df.replace('十六夜咲夜', '十六夜 咲夜', regex=True)
    df=df.replace("（[0-9]+）", "", regex=True)
    if(i<1):
        df.columns= ["名前", "","" ,"順位","","ポイント"]
    elif(i<2):
        df.columns= ['順位', '名前', 'ポイント','コメント']
    elif(i<3):
        df.columns= ['順位', '名前','前回', 'ポイント','コメント']
    elif(i<4):
        df.columns= ['順位', '前回','名前', 'ポイント','一押し','コメント']
    else:
        try:
            df.columns=['順位', '前回','前々','名前', 'ポイント', '一押し','コメント']
        except:
            pass
#    df.columns=[s+str(i+1) if not s in ["名前"] else s for s in df.columns ]  
    dpoint=pd.DataFrame()
    dpoint["名前"]=df["名前"]
    dpoint["ポイント"+str(i+1)]=df["ポイント"]
    chars.append(dpoint)
    
    drank=pd.DataFrame()
    drank["名前"]=df["名前"]
    drank["順位"+str(i+1)]=df["順位"]
    chars_rank.append(drank)
    print(dpoint.head(1))
# Out:
#        名前  ポイント1
# 0  十六夜 咲夜     95
#        名前 ポイント2
# 0  十六夜 咲夜   564
#        名前  ポイント3
# 0  霧雨 魔理沙    785
#        名前  ポイント4
# 0  霧雨 魔理沙   1301
#       名前  ポイント5
# 0  博麗 霊夢   3927
#       名前  ポイント6
# 0  博麗 霊夢   5739
#       名前  ポイント7
# 0  博麗 霊夢   7731
#       名前  ポイント8
# 0  博麗 霊夢   8175
#       名前  ポイント9
# 0  博麗 霊夢   9583
#       名前  ポイント10
# 0  博麗 霊夢    7314
#         名前  ポイント11
# 0  古明地 こいし    7859
#       名前  ポイント12
# 0  博麗 霊夢   15427
#       名前  ポイント13
# 0  博麗 霊夢   10674
#       名前  ポイント14
# 0  博麗 霊夢    8574
#       名前  ポイント15
# 0  博麗 霊夢    6887
#       名前  ポイント16
# 0  魂魄 妖夢    9841
#       名前  ポイント17
# 0  魂魄 妖夢  12,951
#       名前  ポイント18
# 0  魂魄 妖夢  12,951
#               名前  ポイント19
# 0  フランドール・スカーレット  16,723

# %% [markdown]
# ## キャラクターのポイント、ランキングの全期間合併

# %%
ranking=chars_rank[0]
for c in chars_rank[1:]:
    try:
        ranking=pd.merge(ranking,c,on="名前",how='outer')
    except:
        print(c)

# %%
rankingT
# Out:
#          0       1      2     3            4     5              6    \
# 名前    十六夜 咲夜  霧雨 魔理沙  博麗 霊夢   チルノ  パチュリー・ノーレッジ     橙  フランドール・スカーレット
# 順位1       1位       -     3位    4位           5位    6位             7位
# 順位2      1.0     2.0    3.0  16.0          7.0  12.0           15.0
# 順位3      3.0     1.0    6.0  21.0         14.0  17.0           15.0
# 順位4      3.0     1.0    2.0  19.0         10.0  27.0           13.0
# 順位5      4.0     2.0    1.0  15.0         11.0  27.0           10.0
# 順位6      2.0     3.0    1.0  18.0         14.0  36.0           12.0
# 順位7      4.0     3.0    1.0  23.0         16.0  44.0           10.0
# 順位8      2.0     5.0    1.0  23.0         17.0  51.0            9.0
# 順位9      3.0     5.0    1.0  25.0         17.0  53.0            6.0
# 順位10     4.0     2.0    1.0  32.0         18.0  61.0            5.0
# 順位11     4.0     3.0    2.0  37.0         19.0  54.0            5.0
# 順位12     4.0     2.0    1.0  35.0         20.0  55.0            5.0
# 順位13     5.0     2.0    1.0  35.0         20.0  59.0            6.0
# 順位14     5.0     2.0    1.0  31.0         21.0  61.0            6.0
# 順位15     7.0     2.0    1.0  24.0         20.0  63.0            6.0
# 順位16     7.0     4.0    2.0  24.0         18.0  61.0            5.0
# 順位17     6.0     2.0    3.0  18.0         19.0  61.0            5.0
# 順位18     6.0     2.0    3.0  18.0         19.0  61.0            5.0
# 順位19     5.0     2.0    3.0  15.0         19.0  56.0            1.0
#
#               7            8     9    ...    260   261    262     263     264  \
# 名前    レミリア・スカーレット  アリス・マーガトロイド    魅魔  ...  天弓 千亦  菅牧 典  飯綱丸 龍  姫虫 百々世  豪徳寺 ミケ
# 順位1            8位           9位   10位  ...    NaN   NaN    NaN     NaN     NaN
# 順位2          10.0          8.0  21.0  ...    NaN   NaN    NaN     NaN     NaN
# 順位3           8.0         10.0  26.0  ...    NaN   NaN    NaN     NaN     NaN
# 順位4          11.0          5.0  39.0  ...    NaN   NaN    NaN     NaN     NaN
# 順位5           5.0          8.0  36.0  ...    NaN   NaN    NaN     NaN     NaN
# 順位6           5.0          8.0  45.0  ...    NaN   NaN    NaN     NaN     NaN
# 順位7           5.0          6.0  56.0  ...    NaN   NaN    NaN     NaN     NaN
# 順位8           4.0          7.0  61.0  ...    NaN   NaN    NaN     NaN     NaN
# 順位9           4.0          2.0  71.0  ...    NaN   NaN    NaN     NaN     NaN
# 順位10          7.0          6.0  79.0  ...    NaN   NaN    NaN     NaN     NaN
# 順位11          7.0         10.0  81.0  ...    NaN   NaN    NaN     NaN     NaN
# 順位12          7.0          9.0  89.0  ...    NaN   NaN    NaN     NaN     NaN
# 順位13          7.0          9.0  88.0  ...    NaN   NaN    NaN     NaN     NaN
# 順位14          7.0          9.0  94.0  ...    NaN   NaN    NaN     NaN     NaN
# 順位15          5.0         10.0  87.0  ...    NaN   NaN    NaN     NaN     NaN
# 順位16          6.0         11.0  81.0  ...    NaN   NaN    NaN     NaN     NaN
# 順位17          7.0         12.0  82.0  ...   44.0  55.0   57.0    62.0    89.0
# 順位18          7.0         12.0  82.0  ...   44.0  55.0   57.0    62.0    89.0
# 順位19          7.0         11.0  75.0  ...   52.0  57.0   61.0    83.0   106.0
#
#          265     266    267   268    269
# 名前    玉造 魅須丸  山城 たかね  駒草 山如  饕餮尤魔  宮出口瑞霊
# 順位1      NaN     NaN    NaN   NaN    NaN
# 順位2      NaN     NaN    NaN   NaN    NaN
# 順位3      NaN     NaN    NaN   NaN    NaN
# 順位4      NaN     NaN    NaN   NaN    NaN
# 順位5      NaN     NaN    NaN   NaN    NaN
# 順位6      NaN     NaN    NaN   NaN    NaN
# 順位7      NaN     NaN    NaN   NaN    NaN
# 順位8      NaN     NaN    NaN   NaN    NaN
# 順位9      NaN     NaN    NaN   NaN    NaN
# 順位10     NaN     NaN    NaN   NaN    NaN
# 順位11     NaN     NaN    NaN   NaN    NaN
# 順位12     NaN     NaN    NaN   NaN    NaN
# 順位13     NaN     NaN    NaN   NaN    NaN
# 順位14     NaN     NaN    NaN   NaN    NaN
# 順位15     NaN     NaN    NaN   NaN    NaN
# 順位16     NaN     NaN    NaN   NaN    NaN
# 順位17   106.0   119.0  138.0   NaN    NaN
# 順位18   106.0   119.0  138.0   NaN    NaN
# 順位19   123.0   122.0  143.0  53.0  138.0
#
# [20 rows x 270 columns]

# %% [markdown]
# #### 転置して上位だけを取得してみる

# %%
rankingT.columns=rankingT.iloc[0]

# %%
rankingT=rankingT.drop("名前")

# %%
rankingT=rankingT.replace('位','',regex=True)

# %%
rankingT
# Out:
# 名前   十六夜 咲夜 霧雨 魔理沙 博麗 霊夢   チルノ パチュリー・ノーレッジ     橙 フランドール・スカーレット レミリア・スカーレット  \
# 順位1       1      -     3     4           5     6             7           8
# 順位2     1.0    2.0   3.0  16.0         7.0  12.0          15.0        10.0
# 順位3     3.0    1.0   6.0  21.0        14.0  17.0          15.0         8.0
# 順位4     3.0    1.0   2.0  19.0        10.0  27.0          13.0        11.0
# 順位5     4.0    2.0   1.0  15.0        11.0  27.0          10.0         5.0
# 順位6     2.0    3.0   1.0  18.0        14.0  36.0          12.0         5.0
# 順位7     4.0    3.0   1.0  23.0        16.0  44.0          10.0         5.0
# 順位8     2.0    5.0   1.0  23.0        17.0  51.0           9.0         4.0
# 順位9     3.0    5.0   1.0  25.0        17.0  53.0           6.0         4.0
# 順位10    4.0    2.0   1.0  32.0        18.0  61.0           5.0         7.0
# 順位11    4.0    3.0   2.0  37.0        19.0  54.0           5.0         7.0
# 順位12    4.0    2.0   1.0  35.0        20.0  55.0           5.0         7.0
# 順位13    5.0    2.0   1.0  35.0        20.0  59.0           6.0         7.0
# 順位14    5.0    2.0   1.0  31.0        21.0  61.0           6.0         7.0
# 順位15    7.0    2.0   1.0  24.0        20.0  63.0           6.0         5.0
# 順位16    7.0    4.0   2.0  24.0        18.0  61.0           5.0         6.0
# 順位17    6.0    2.0   3.0  18.0        19.0  61.0           5.0         7.0
# 順位18    6.0    2.0   3.0  18.0        19.0  61.0           5.0         7.0
# 順位19    5.0    2.0   3.0  15.0        19.0  56.0           1.0         7.0
#
# 名前   アリス・マーガトロイド    魅魔  ... 天弓 千亦  菅牧 典 飯綱丸 龍 姫虫 百々世 豪徳寺 ミケ 玉造 魅須丸 山城 たかね  \
# 順位1            9    10  ...   NaN   NaN   NaN    NaN    NaN    NaN    NaN
# 順位2          8.0  21.0  ...   NaN   NaN   NaN    NaN    NaN    NaN    NaN
# 順位3         10.0  26.0  ...   NaN   NaN   NaN    NaN    NaN    NaN    NaN
# 順位4          5.0  39.0  ...   NaN   NaN   NaN    NaN    NaN    NaN    NaN
# 順位5          8.0  36.0  ...   NaN   NaN   NaN    NaN    NaN    NaN    NaN
# 順位6          8.0  45.0  ...   NaN   NaN   NaN    NaN    NaN    NaN    NaN
# 順位7          6.0  56.0  ...   NaN   NaN   NaN    NaN    NaN    NaN    NaN
# 順位8          7.0  61.0  ...   NaN   NaN   NaN    NaN    NaN    NaN    NaN
# 順位9          2.0  71.0  ...   NaN   NaN   NaN    NaN    NaN    NaN    NaN
# 順位10         6.0  79.0  ...   NaN   NaN   NaN    NaN    NaN    NaN    NaN
# 順位11        10.0  81.0  ...   NaN   NaN   NaN    NaN    NaN    NaN    NaN
# 順位12         9.0  89.0  ...   NaN   NaN   NaN    NaN    NaN    NaN    NaN
# 順位13         9.0  88.0  ...   NaN   NaN   NaN    NaN    NaN    NaN    NaN
# 順位14         9.0  94.0  ...   NaN   NaN   NaN    NaN    NaN    NaN    NaN
# 順位15        10.0  87.0  ...   NaN   NaN   NaN    NaN    NaN    NaN    NaN
# 順位16        11.0  81.0  ...   NaN   NaN   NaN    NaN    NaN    NaN    NaN
# 順位17        12.0  82.0  ...  44.0  55.0  57.0   62.0   89.0  106.0  119.0
# 順位18        12.0  82.0  ...  44.0  55.0  57.0   62.0   89.0  106.0  119.0
# 順位19        11.0  75.0  ...  52.0  57.0  61.0   83.0  106.0  123.0  122.0
#
# 名前    駒草 山如  饕餮尤魔  宮出口瑞霊
# 順位1     NaN   NaN    NaN
# 順位2     NaN   NaN    NaN
# 順位3     NaN   NaN    NaN
# 順位4     NaN   NaN    NaN
# 順位5     NaN   NaN    NaN
# 順位6     NaN   NaN    NaN
# 順位7     NaN   NaN    NaN
# 順位8     NaN   NaN    NaN
# 順位9     NaN   NaN    NaN
# 順位10    NaN   NaN    NaN
# 順位11    NaN   NaN    NaN
# 順位12    NaN   NaN    NaN
# 順位13    NaN   NaN    NaN
# 順位14    NaN   NaN    NaN
# 順位15    NaN   NaN    NaN
# 順位16    NaN   NaN    NaN
# 順位17  138.0   NaN    NaN
# 順位18  138.0   NaN    NaN
# 順位19  143.0  53.0  138.0
#
# [19 rows x 270 columns]

# %%
rankingT['霧雨 魔理沙'][0]=1

# %%
rankingT9=rankingT.iloc[:,:9].astype('int')
rankingT9
# Out:
# 名前    十六夜 咲夜  霧雨 魔理沙  博麗 霊夢  チルノ  パチュリー・ノーレッジ   橙  フランドール・スカーレット  レミリア・スカーレット  \
# 順位1        1       1      3    4            5   6              7            8
# 順位2        1       2      3   16            7  12             15           10
# 順位3        3       1      6   21           14  17             15            8
# 順位4        3       1      2   19           10  27             13           11
# 順位5        4       2      1   15           11  27             10            5
# 順位6        2       3      1   18           14  36             12            5
# 順位7        4       3      1   23           16  44             10            5
# 順位8        2       5      1   23           17  51              9            4
# 順位9        3       5      1   25           17  53              6            4
# 順位10       4       2      1   32           18  61              5            7
# 順位11       4       3      2   37           19  54              5            7
# 順位12       4       2      1   35           20  55              5            7
# 順位13       5       2      1   35           20  59              6            7
# 順位14       5       2      1   31           21  61              6            7
# 順位15       7       2      1   24           20  63              6            5
# 順位16       7       4      2   24           18  61              5            6
# 順位17       6       2      3   18           19  61              5            7
# 順位18       6       2      3   18           19  61              5            7
# 順位19       5       2      3   15           19  56              1            7
#
# 名前    アリス・マーガトロイド
# 順位1             9
# 順位2             8
# 順位3            10
# 順位4             5
# 順位5             8
# 順位6             8
# 順位7             6
# 順位8             7
# 順位9             2
# 順位10            6
# 順位11           10
# 順位12            9
# 順位13            9
# 順位14            9
# 順位15           10
# 順位16           11
# 順位17           12
# 順位18           12
# 順位19           11

# %%
rankingT9.plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### 得票数(ポイント)

# %%
pdd=chars[0]
for c in chars[1:]:
    try:
        pdd=pd.merge(pdd,c,on="名前",how='outer')
    except:
        print(c)

# %%
pdd
# Out:
#               名前  ポイント1 ポイント2  ポイント3   ポイント4   ポイント5   ポイント6   ポイント7   ポイント8  \
# 0         十六夜 咲夜   95.0   564  585.0  1165.0  3154.0  5433.0  6763.0  7246.0
# 1         霧雨 魔理沙   95.0   532  785.0  1301.0  3867.0  5380.0  6766.0  6750.0
# 2          博麗 霊夢   62.0   293  426.0  1245.0  3927.0  5739.0  7731.0  8175.0
# 3            チルノ   51.0    65   53.0   330.0  2075.0  2604.0  3243.0  3196.0
# 4    パチュリー・ノーレッジ   46.0   195  104.0   743.0  2474.0  3450.0  4259.0  4298.0
# ..           ...    ...   ...    ...     ...     ...     ...     ...     ...
# 265       玉造 魅須丸    NaN   NaN    NaN     NaN     NaN     NaN     NaN     NaN
# 266       山城 たかね    NaN   NaN    NaN     NaN     NaN     NaN     NaN     NaN
# 267        駒草 山如    NaN   NaN    NaN     NaN     NaN     NaN     NaN     NaN
# 268         饕餮尤魔    NaN   NaN    NaN     NaN     NaN     NaN     NaN     NaN
# 269        宮出口瑞霊    NaN   NaN    NaN     NaN     NaN     NaN     NaN     NaN
#
#       ポイント9  ポイント10  ポイント11   ポイント12   ポイント13  ポイント14  ポイント15  ポイント16  ポイント17  \
# 0    8635.0  5848.0  6241.0  10195.0   8282.0  6529.0  5119.0  7853.0  10,015
# 1    8028.0  6495.0  7227.0  10969.0   8990.0  7386.0  5950.0  8626.0  11,816
# 2    9583.0  7314.0  7332.0  15427.0  10674.0  8574.0  6887.0  8913.0  11,404
# 3    3604.0  2006.0  2074.0   3275.0   2679.0  2489.0  2264.0  3020.0   4,226
# 4    4777.0  3039.0  2823.0   4495.0   3676.0  3022.0  2413.0  3532.0   4,128
# ..      ...     ...     ...      ...      ...     ...     ...     ...     ...
# 265     NaN     NaN     NaN      NaN      NaN     NaN     NaN     NaN     556
# 266     NaN     NaN     NaN      NaN      NaN     NaN     NaN     NaN     356
# 267     NaN     NaN     NaN      NaN      NaN     NaN     NaN     NaN     171
# 268     NaN     NaN     NaN      NaN      NaN     NaN     NaN     NaN     NaN
# 269     NaN     NaN     NaN      NaN      NaN     NaN     NaN     NaN     NaN
#
#      ポイント18  ポイント19
# 0    10,015  13,787
# 1    11,816  16,578
# 2    11,404  15,679
# 3     4,226   5,850
# 4     4,128   5,194
# ..      ...     ...
# 265     556     363
# 266     356     374
# 267     171     174
# 268     NaN   1,854
# 269     NaN     219
#
# [270 rows x 20 columns]

# %%
pdd.名前
# Out:
# 0           十六夜 咲夜
# 1           霧雨 魔理沙
# 2            博麗 霊夢
# 3              チルノ
# 4      パチュリー・ノーレッジ
#           ...
# 265         玉造 魅須丸
# 266         山城 たかね
# 267          駒草 山如
# 268           饕餮尤魔
# 269          宮出口瑞霊
# Name: 名前, Length: 270, dtype: object

# %% [markdown]
# #### 転置して上位だけを取得してみる

# %%
pddT9=pdd.T.iloc[:,:9]
pddT9.columns=pddT9.iloc[0]
pddT9=pddT9.drop("名前")

# %%
print(pddT9.columns)
print(pddT9.iloc[0])
# Out:
# Int64Index([0, 1, 2, 3, 4, 5, 6, 7, 8], dtype='int64')
# 0           十六夜 咲夜
# 1           霧雨 魔理沙
# 2            博麗 霊夢
# 3              チルノ
# 4      パチュリー・ノーレッジ
# 5                橙
# 6    フランドール・スカーレット
# 7      レミリア・スカーレット
# 8      アリス・マーガトロイド
# Name: 名前, dtype: object

# %%
pddT9=pddT9.astype('int')
pddT9
# Out:
# 名前      十六夜 咲夜  霧雨 魔理沙  博麗 霊夢   チルノ  パチュリー・ノーレッジ     橙  フランドール・スカーレット  \
# ポイント1       95      95     62    51           46    43             32
# ポイント2      564     532    293    65          195   142             93
# ポイント3      585     785    426    53          104    55             96
# ポイント4     1165    1301   1245   330          743   157            465
# ポイント5     3154    3867   3927  2075         2474   920           2497
# ポイント6     5433    5380   5739  2604         3450  1399           3654
# ポイント7     6763    6766   7731  3243         4259  1684           5365
# ポイント8     7246    6750   8175  3196         4298  1545           5961
# ポイント9     8635    8028   9583  3604         4777  1637           7824
# ポイント10    5848    6495   7314  2006         3039   944           5488
# ポイント11    6241    7227   7332  2074         2823  1077           5972
# ポイント12   10195   10969  15427  3275         4495  1862           9844
# ポイント13    8282    8990  10674  2679         3676  1492           8202
# ポイント14    6529    7386   8574  2489         3022  1207           6497
# ポイント15    5119    5950   6887  2264         2413   909           5222
# ポイント16    7853    8626   8913  3020         3532  1290           8497
# ポイント17   10015   11816  11404  4226         4128  1264          10335
# ポイント18   10015   11816  11404  4226         4128  1264          10335
# ポイント19   13787   16578  15679  5850         5194  1780          16723
#
# 名前      レミリア・スカーレット  アリス・マーガトロイド
# ポイント1            28           27
# ポイント2           162          184
# ポイント3           174          179
# ポイント4           688          919
# ポイント5          3083         2574
# ポイント6          4945         4065
# ポイント7          6747         6238
# ポイント8          6920         6373
# ポイント9          8205         9265
# ポイント10         5089         5383
# ポイント11         5327         4945
# ポイント12         9091         7834
# ポイント13         7533         6563
# ポイント14         6304         5148
# ポイント15         5453         3908
# ポイント16         8294         4749
# ポイント17         9482         5608
# ポイント18         9482         5608
# ポイント19        12981         6909

# %%
print(pddT9.dtypes)
# Out:
# 名前
# 十六夜 咲夜           int64
# 霧雨 魔理沙           int64
# 博麗 霊夢            int64
# チルノ              int64
# パチュリー・ノーレッジ      int64
# 橙                int64
# フランドール・スカーレット    int64
# レミリア・スカーレット      int64
# アリス・マーガトロイド      int64
# dtype: object

# %%
import shutil
from pathlib import Path

config_dir = Path(mpl.get_configdir())
config_dir.mkdir(exist_ok=True, parents=True)

default_config_path = Path(mpl.__file__).parent / "mpl-data/matplotlibrc"
config_path = config_dir / "matplotlibrc"
shutil.copyfile(default_config_path, config_path)
# Out:
# PosixPath('/home/xiangze/.config/matplotlib/matplotlibrc')

# %%
# !sed -i "s/#font.family:  sans-serif/font.family: Hiragino Maru Gothic Pro/" ~/.config/matplotlib/matplotlibrc

# %%
plt.plot(pddT9["チルノ"].values)
plt.title("チルノ")
# Out:
# Text(0.5, 1.0, 'チルノ')

# %%
pddT9.plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# # 音楽

# %%
for f in musicfiles:
