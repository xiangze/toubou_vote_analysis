# %% [markdown]
# # 投票ポイント総数

# %%
import pandas as pd

# %%
sousuu=pd.read_csv("data/sousuu.csv")

# %%
sousuu
# Out:
#         第     年    キャラ       音楽       作品  Unnamed: 5  Unnamed: 6
# 0       1  2002    544    678.0      NaN         NaN         NaN
# 1       2  2003   1195    945.0    711.0       728.0         NaN
# 2       3  2004   4942   2636.0      NaN      3525.0      2894.0
# 3       4  2005   4426   3801.0   2997.0         NaN         NaN
# 4   spell  2006   1602      NaN      NaN         NaN         NaN
# 5       5  2008  12220  10787.0   8501.0         NaN         NaN
# 6       6  2009  22087  18774.0  15156.0         NaN         NaN
# 7       7  2010  33449  28110.0  22245.0         NaN         NaN
# 8       8  2011  35946  29285.0  21499.0         NaN         NaN
# 9       9  2012  43737  32842.0  20105.0         NaN         NaN
# 10     10  2014  31040  23283.0  15494.0         NaN         NaN
# 11     11  2015  32244  20843.0  10636.0         NaN         NaN
# 12     12  2016  42419  32356.0  24742.0     18268.0         NaN
# ...

# %%
sousuu_main=sousuu.drop([4,17])

# %%
sousuu_main["キャラ"].plot(figsize=(10,10),marker='+',)
sousuu_main["音楽"].plot(figsize=(10,10),marker='+',)
sousuu_main["作品"].plot(figsize=(10,10),marker='+',)
# Out:
# <AxesSubplot:>

# %% [markdown]
# 第８回以降はポイント数に増減が見られる。
